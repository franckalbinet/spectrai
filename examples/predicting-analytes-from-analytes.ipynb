# %% [markdown]
# PREDICTING ANALYTE(S) FROM ANALYTE(S)
#
# ---

# %% [markdown]
# ### 1. Google Colab runtime setup [Optional]

# %%
# Clone and install spectrai package 
# !git clone https://github.com/franckalbinet/spectrai.git 
# !pip install /content/spectrai

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
# Prepare /root folder content
# !cp -r /content/drive/My\ Drive/Colab\ Notebooks/data/data_spectrai /root

# %%
# Create configuration file
# !mkdir /root/.spectrai_config & cp /content/spectrai/config.toml /root/.spectrai_config

# %% [markdown]
# ### 2. Import packages

# %%
from spectrai.datasets.kssl import (get_tax_orders_lookup_tbl, load_data,
                                    load_analytes, load_data_analytes, load_fact_tbl, load_spectra)

from spectrai.vis.spectra import (plot_spectra)
import pandas as pd
import numpy as np
from tqdm import tqdm

from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

import xgboost as xgb

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### 3.  Load KSSL dataset for analyte(s) -> analyte(s) modeling

# %%
# Choosing analytes to be used as features and target(s)
targets = [725]
# Selected analytes where nb_samples > 30000 (i.e most frequently measured analytes)
features = [622, 623, 624, 420, 723, 724, 722,726, 750, 481, 268, 339, 334, 342, 338, 337, 343, 340, 341, 417, 65, 66, 67]

# Tetsuya features
tetsuya_features = [383, 368]

# Selected features
features_selected = [383, 723, 481, 726, 268, 417]

# %%
X, X_names, y, y_names, instances_id = load_data_analytes(features=features, targets=targets)

# %%
print('X shape: ', X.shape)
print('X approx. memory size: {:.2f} MB'.format(X.nbytes / 10**6))
print('y approx. memory size: {:.2f} MB'.format(y.nbytes / 10**6))
print('Features: ', X_names)
print('Target variable: ', y_names)
# Out:
# X shape:  (20862, 23)
# X approx. memory size: 3.84 MB
# y approx. memory size: 0.17 MB
# Features:  [622 623 624 420 723 724 722 726 750 481 268 339 334 342 338 337 343 340
#  341 417  65  66  67]
# Target variable:  [725]

# %% [markdown]
# ### 4.  Modeling

# %% [markdown]
# * **Utilities functions**

# %%
def prettify_features_importance(features_importance, ascending_sort=False, label='feature_importance'):
    df_analytes = load_analytes()
    df = df_analytes.set_index('analyte_id').loc[X_names,:]
    df[label] = features_importance
    return df \
        .sort_values(by=[label], ascending=ascending_sort) \
        .reset_index()[['analyte_id', 'analyte_name', label]]

# %% [markdown]
# * **Assess Correlation between features and target**

# %%
prettify_features_importance(np.corrcoef(np.c_[X, y].T)[:, -1][:-1], label='corr. with potassium (725)')
# Out:
#     analyte_id                                       analyte_name  \
# 0          723           CEC, NH4OAc, pH 7.0, 2M KCl displacement
# 1          481                      pH, 1:2 Soil-CaCl2 Suspension
# 2          726    Sodium, NH4OAc Extractable, 2M KCl displacement
# 3          268                      pH, 1:1 Soil-Water Suspension
# 4          417            Water Retention, 15 Bar, <2mm,  Air-dry
# 5          724  Magnesium, NH4OAc Extractable, 2M KCl displace...
# 6          420                             Ratio, Air-dry/Ovendry
# 7          334                                               Clay
# 8          337                                 Clay, Noncarbonate
# 9          722   Calcium, NH4OAc Extractable, 2M KCl displacement
# 10         343                                         Silt, Fine
# 11          67          Manganese, Dithionite Citrate Extractable
# 12         622                                  Carbon, Total NCS
# 13         623                                Nitrogen, Total NCS
# 14         342                                    Sand, Very Fine
# 15         624                                  Sulfur, Total NCS
# 16         750  Volume, CEC, NH4OAc, Syringe Extract, 2M KCl d...
# 17          66               Iron, Dithionite Citrate Extractable
# 18          65           Aluminum, Dithionite Citrate Extractable
# 19         341                                  Sand, Very Coarse
# 20         338                                       Sand, Coarse
# 21         339                                         Sand, Fine
# 22         340                                       Sand, Medium
#
#     corr. with potassium (725)
# 0                     0.383707
# 1                     0.297316
# 2                     0.286813
# 3                     0.282177
# 4                     0.277948
# 5                     0.260085
# 6                     0.248446
# 7                     0.231424
# 8                     0.221178
# 9                     0.212286
# 10                    0.121452
# 11                    0.112394
# 12                    0.111233
# 13                    0.069469
# 14                    0.023759
# 15                    0.011910
# 16                   -0.029034
# 17                   -0.031615
# 18                   -0.063453
# 19                   -0.069376
# 20                   -0.114141
# 21                   -0.200422
# 22                   -0.211410

# %% [markdown]
# * **Data preparation**

# %%
X_subset = X
y_subset = y

# %%
X_subset = StandardScaler().fit_transform(X_subset)

# %%
# Classical train, test split
X_train, X_test, y_train, y_test = train_test_split(X_subset, y_subset, test_size=0.20, random_state=42)

print('X train shape: ', X_train.shape)
print('X test shape: ', X_test.shape)
print('y train shape: ', y_train.shape)
# Out:
# X train shape:  (16689, 23)
# X test shape:  (4173, 23)
# y train shape:  (16689, 1)

# %% [markdown]
# * **Linear Regression**

# %%
lr = LinearRegression()
lr.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
print('# of training sample: {}'.format(X_train.shape[0]))
print('Train R2 score: {:.3f}'.format(lr.score(X_train, y_train)))
print('Test R2 score: {:.3f}'.format(lr.score(X_test, y_test)))
# Out:
# # of training sample: 16689
# Train R2 score: 0.291
# Test R2 score: 0.288

# %%
prettify_features_importance(lr.coef_.tolist()[0])
# Out:
#     analyte_id                                       analyte_name  \
# 0          723           CEC, NH4OAc, pH 7.0, 2M KCl displacement
# 1          481                      pH, 1:2 Soil-CaCl2 Suspension
# 2          726    Sodium, NH4OAc Extractable, 2M KCl displacement
# 3          334                                               Clay
# 4          624                                  Sulfur, Total NCS
# 5          417            Water Retention, 15 Bar, <2mm,  Air-dry
# 6           67          Manganese, Dithionite Citrate Extractable
# 7          750  Volume, CEC, NH4OAc, Syringe Extract, 2M KCl d...
# 8          623                                Nitrogen, Total NCS
# 9          342                                    Sand, Very Fine
# 10         338                                       Sand, Coarse
# 11          66               Iron, Dithionite Citrate Extractable
# 12         341                                  Sand, Very Coarse
# 13         722   Calcium, NH4OAc Extractable, 2M KCl displacement
# 14         268                      pH, 1:1 Soil-Water Suspension
# 15         340                                       Sand, Medium
# 16          65           Aluminum, Dithionite Citrate Extractable
# 17         343                                         Silt, Fine
# 18         339                                         Sand, Fine
# 19         622                                  Carbon, Total NCS
# 20         724  Magnesium, NH4OAc Extractable, 2M KCl displace...
# 21         420                             Ratio, Air-dry/Ovendry
# 22         337                                 Clay, Noncarbonate
#
#     feature_importance
# 0             0.391121
# 1             0.183592
# 2             0.140379
# 3             0.114973
# 4             0.069841
# 5             0.031211
# 6             0.027836
# 7             0.014513
# 8             0.006921
# 9             0.004183
# 10            0.002418
# 11           -0.016938
# 12           -0.024749
# 13           -0.027811
# 14           -0.036448
# 15           -0.042766
# 16           -0.051784
# 17           -0.060619
# 18           -0.068689
# 19           -0.079785
# 20           -0.084633
# 21           -0.128049
# 22           -0.154011

# %% [markdown]
# * **XGBoost**

# %%
xgb_reg = xgb.XGBRegressor(n_estimators=500)
xgb_reg.fit(X_train, y_train)
# Out:
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=1, gamma=0, gpu_id=-1,
#              importance_type='gain', interaction_constraints='',
#              learning_rate=0.300000012, max_delta_step=0, max_depth=6,
#              min_child_weight=1, missing=nan, monotone_constraints='()',
#              n_estimators=500, n_jobs=0, num_parallel_tree=1, random_state=0,
#              reg_alpha=0, reg_lambda=1, scale_pos_weight=1, subsample=1,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
print('# of training sample: {}'.format(X_train.shape[0]))
print('Train R2 score: {:.3f}'.format(xgb_reg.score(X_train, y_train)))
print('Test R2 score: {:.3f}'.format(xgb_reg.score(X_test, y_test)))
# Out:
# # of training sample: 16689
# Train R2 score: 0.996
# Test R2 score: 0.566

# %%
prettify_features_importance(xgb_reg.feature_importances_)
# Out:
#     analyte_id                                       analyte_name  \
# 0          723           CEC, NH4OAc, pH 7.0, 2M KCl displacement
# 1          726    Sodium, NH4OAc Extractable, 2M KCl displacement
# 2          722   Calcium, NH4OAc Extractable, 2M KCl displacement
# 3          420                             Ratio, Air-dry/Ovendry
# 4          481                      pH, 1:2 Soil-CaCl2 Suspension
# 5           66               Iron, Dithionite Citrate Extractable
# 6           67          Manganese, Dithionite Citrate Extractable
# 7           65           Aluminum, Dithionite Citrate Extractable
# 8          724  Magnesium, NH4OAc Extractable, 2M KCl displace...
# 9          339                                         Sand, Fine
# 10         623                                Nitrogen, Total NCS
# 11         417            Water Retention, 15 Bar, <2mm,  Air-dry
# 12         334                                               Clay
# 13         268                      pH, 1:1 Soil-Water Suspension
# 14         338                                       Sand, Coarse
# 15         341                                  Sand, Very Coarse
# 16         750  Volume, CEC, NH4OAc, Syringe Extract, 2M KCl d...
# 17         343                                         Silt, Fine
# 18         342                                    Sand, Very Fine
# 19         340                                       Sand, Medium
# 20         337                                 Clay, Noncarbonate
# 21         624                                  Sulfur, Total NCS
# 22         622                                  Carbon, Total NCS
#
#     feature_importance
# 0             0.147796
# 1             0.143232
# 2             0.092605
# 3             0.074821
# 4             0.064489
# 5             0.056164
# 6             0.044407
# 7             0.043099
# 8             0.034143
# 9             0.031400
# 10            0.027280
# 11            0.026592
# 12            0.026243
# 13            0.025868
# 14            0.022030
# 15            0.021875
# 16            0.019905
# 17            0.017796
# 18            0.017477
# 19            0.017456
# 20            0.017070
# 21            0.014266
# 22            0.013989

# %% [markdown]
# ### 5. In-depth analysis of analytes correlation

# %%
corrs = []
for analyte in tqdm(df_fact['analyte_id'].unique().tolist()):
    X, _, y, _, _ = load_data_analytes(features=[analyte], targets=[725])
    corrs.append({
        'analyte_id': analyte,
        'correlation': np.corrcoef(np.c_[X, y].T)[:, -1][:-1].item(),
        'nb_samples': X.shape[0]
    })

# %%
df_corrs = pd.DataFrame(corrs).dropna()

mask_not_target = df_corrs['analyte_id'] != 725
mask_min_nb = df_corrs['nb_samples'] > 30
df_corrs = df_corrs.loc[mask_not_target & mask_min_nb, :]
df_corrs['abs_correlation'] = np.abs(df_corrs['correlation'])
df_corrs = df_corrs.sort_values(by=['abs_correlation', 'nb_samples'], ascending=False)

# %%
df_corrs.head()
# Out:
#      analyte_id  correlation  nb_samples  abs_correlation
# 267        1065     0.920296        1657         0.920296
# 219        1167     0.742382         770         0.742382
# 339         776    -0.711802          32         0.711802
# 341         794    -0.670244          32         0.670244
# 201         839     0.625547         731         0.625547

# %%
df_corrs = df_corrs.merge(df_analytes[['analyte_id', 'analyte_name', 'uom_abbrev']], 
                          on='analyte_id')[['analyte_id', 'analyte_name', 'uom_abbrev', 'correlation', 'nb_samples', 'abs_correlation']]

# %%
df_corrs.head(25)
# Out:
#     analyte_id                                       analyte_name  uom_abbrev  \
# 0         1065            Potassium, Element Mehlich3 Extractable       mg/kg
# 1         1167                       Potassium, Water Extractable       µg/kg
# 2          776                                Carbon, pom mineral         g/g
# 3          794                              FMOD, Bio, whole soil        (NA)
# 4          839       Phosphorus, Anion Resin Extractable, 24 hour       mg/kg
# 5          838        Phosphorus, Anion Resin Extractable, 1 hour       mg/kg
# 6          364        Electrical Conductivity, Predict, 1:2 (w/w)        dS/m
# 7         1406                       p-nitrophenol, ß-Glucosidase    mg/kg/hr
# 8          726    Sodium, NH4OAc Extractable, 2M KCl displacement  cmol(+)/kg
# 9          772                                        Carbon, pom         g/g
# 10          92                                    Nitrate, 1M KCl       mg/kg
# 11         778                                Sulfur, pom mineral         g/g
# 12         724  Magnesium, NH4OAc Extractable, 2M KCl displace...  cmol(+)/kg
# 13         690                      Nitrogen, Mineralizable (EPA)        mg/L
# 14        1418           Sand, Fine, Ethanol Disp, Air-dry, Ultra        % wt
# 15        1416                 Clay, Ethanol Disp, Air-dry, Ultra        % wt
# 16         344                       Clay PSDA, Ultrasonic, Pipet        % wt
# 17         777                              Nitrogen, pom mineral         g/g
# 18        1419         Sand, Medium, Ethanol Disp, Air-dry, Ultra        % wt
# 19         140                    Clay-Coated Quartz, petro_count       count
# 20         379                      Potassium, Saturation Extract   mmol(+)/L
# 21         269                          Phosphorus, Water Soluble       mg/kg
# 22         417            Water Retention, 15 Bar, <2mm,  Air-dry        % wt
# 23        1146                               Boron, water extract       µg/kg
# 24         274                      Phosphorus, Olsen Extractable       mg/kg
#
#     correlation  nb_samples  abs_correlation
# 0      0.920296        1657         0.920296
# 1      0.742382         770         0.742382
# 2     -0.711802          32         0.711802
# 3     -0.670244          32         0.670244
# 4      0.625547         731         0.625547
# 5      0.592839         730         0.592839
# 6      0.589672       31644         0.589672
# 7      0.584318        5783         0.584318
# 8      0.572129       55661         0.572129
# 9     -0.571535          32         0.571535
# 10     0.532135         480         0.532135
# 11    -0.482820          32         0.482820
# 12     0.475898       55663         0.475898
# 13     0.454320         159         0.454320
# 14    -0.452844          77         0.452844
# 15     0.432789          77         0.432789
# 16     0.431298          42         0.431298
# 17     0.429817          32         0.429817
# 18    -0.414512          77         0.414512
# 19     0.400748          37         0.400748
# 20     0.368207        8449         0.368207
# 21     0.345232        1453         0.345232
# 22     0.337041       39199         0.337041
# 23     0.336861         710         0.336861
# 24     0.323652       15790         0.323652

# %%
df_corrs.to_excel('data/correlations_with_potassium.xlsx', float_format="%.2f", index=False)
