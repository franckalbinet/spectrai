# %% [markdown]
# PREDICTING WITH PARTIAL LEAST SQUARES
#
# ---

# %% [markdown]
# ### 1. Google Colab runtime setup [Optional]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Clone and install spectrai package 
# !git clone https://github.com/franckalbinet/spectrai.git 
# !pip install /content/spectrai

# %%
# Prepare /root folder content
# !cp -r /content/drive/My\ Drive/Colab\ Notebooks/data/data_spectrai /root

# %%
# Create configuration file
# !mkdir /root/.spectrai_config & cp /content/spectrai/config.toml /root/.spectrai_config

# %% [markdown]
# ### 2. Import packages

# %%
from spectrai.datasets.kssl import (get_tax_orders_lookup_tbl, get_analytes, load_data)
from spectrai.vis.spectra import plot_spectra
from sklearn.metrics import mean_squared_error, r2_score

from sklearn.model_selection import train_test_split
from sklearn.cross_decomposition import PLSRegression
from sklearn.model_selection import cross_val_predict
from sklearn.base import BaseEstimator, TransformerMixin
from sklearn.pipeline import Pipeline
from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import train_test_split

import numpy as np

from scipy.signal import savgol_filter

import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ### 3. Load KSSL dataset

# %%
# Loading Potassium, NH4OAc
X, X_names, y, y_names, instances_id = load_data([725])

# %%
print('X shape: ', X.shape)
print('X approx. memory size: {} MB'.format(X.nbytes // 10**6))
print('y approx. memory size: {} MB'.format(y.nbytes // 10**6))
print('Wavenumbers: ', X_names)
print('Target variable: ', y_names)
# Out:
# X shape:  (50714, 1764)
# X approx. memory size: 357 MB
# y approx. memory size: 1 MB
# Wavenumbers:  [3999 3997 3995 ...  603  601  599]
# Target variable:  ['lay_depth_to_top' 'order_id' 'calc_value']

# %% [markdown]
# ### 4. Data preparation and preprocessing

# %%
# Display taxonomic orders
get_tax_orders_lookup_tbl()
# Out:
# {'alfisols': 0,
#  'andisols': 7,
#  'aridisols': 11,
#  'entisols': 3,
#  'gelisols': 12,
#  'histosols': 8,
#  'inceptisols': 2,
#  'mollisols': 1,
#  nan: 5,
#  'oxisols': 9,
#  'spodosols': 4,
#  'ultisols': 6,
#  'vertisols': 10}

# %%
# Keeping data with analyte concentration > 0 only and for 'alfisols' taxonomic order only.
TAX_ORDER_ID = 0

idx_y_valid = y[:, -1] > 0
idx_order = y[:,1] == TAX_ORDER_ID
idx = idx_y_valid & idx_order

X_subset = X[idx,:]
y_subset = y[idx,:]

# %%
# Creating train, valid, test sets
X_train, X_test, y_train, y_test = train_test_split(X_subset, y_subset[:, -1], test_size=0.40, random_state=42)

print('X train shape: ', X_train.shape)
print('X test shape: ', X_test.shape)
print('y train shape: ', y_train.shape)
print('y test shape: ', y_test.shape)
# Out:
# X train shape:  (2982, 1764)
# X test shape:  (1988, 1764)
# y train shape:  (2982,)
# y test shape:  (1988,)

# %%
# Custom transformer (To be able to "search grid")
class TakeDerivative(BaseEstimator, TransformerMixin):
    def __init__(self, window_length=11, polyorder=1, deriv=1):
        self.window_length = window_length
        self.polyorder = polyorder
        self.deriv = deriv
        
    def fit(self, X, y=None):
        return self
    
    def transform(self, X, y=None):
        return savgol_filter(X, self.window_length, self.polyorder, self.deriv)

# %% [markdown]
# ### 5. Fit  and fine-tune PLS model

# %%
# Set grid of hyper-parameters values to explore
param_grid = {'deriv__window_length': range(3, 13, 2), # Should be odd
              'deriv__polyorder': range(1, 2),
              'model__n_components': range(2,20)}

# %%
# Setup and fit the pipeline
pipe = Pipeline([('deriv', TakeDerivative()), ('model', PLSRegression())])
grid_search = GridSearchCV(pipe, param_grid, cv=5, scoring='r2', return_train_score=True, verbose=1)
grid_search.fit(X_train, y_train)
# Out:
# Fitting 5 folds for each of 90 candidates, totalling 450 fits
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done 450 out of 450 | elapsed:  4.3min finished
# GridSearchCV(cv=5, error_score='raise-deprecating',
#              estimator=Pipeline(memory=None,
#                                 steps=[('deriv',
#                                         TakeDerivative(deriv=1, polyorder=1,
#                                                        window_length=11)),
#                                        ('model',
#                                         PLSRegression(copy=True, max_iter=500,
#                                                       n_components=2,
#                                                       scale=True, tol=1e-06))],
#                                 verbose=False),
#              iid='warn', n_jobs=None,
#              param_grid={'deriv__polyorder': range(1, 2),
#                          'deriv__window_length': range(3, 13, 2),
#                          'model__n_components': range(2, 20)},
#              pre_dispatch='2*n_jobs', refit=True, return_train_score=True,
#              scoring='r2', verbose=1)

# %%
# What is the "best" combination of hyper-parameters
grid_search.best_params_
# Out:
# {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 16}

# %%
# What is the "best" score
grid_search.best_score_
# Out:
# 0.4461821015526968

# %%
# Listing all grid points and associated score
cvres = grid_search.cv_results_
for mean_train_score, mean_test_score, params in zip(cvres['mean_train_score'], cvres['mean_test_score'], cvres['params']):
  print(mean_train_score, mean_test_score,params)
# Out:
# 0.3167399417375815 0.2962602693684806 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 2}
# 0.3514656105952848 0.3223630053567927 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 3}
# 0.3762522338046416 0.33655192123263894 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 4}
# 0.39764917785284376 0.350928286169803 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 5}
# 0.4246270178548553 0.3763031554323237 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 6}
# 0.4361146054758981 0.3768784586969511 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 7}
# 0.4642720900229068 0.39837036417053223 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 8}
# 0.4818274218555431 0.40651481024697644 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 9}
# 0.5015772664685291 0.41892688982108256 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 10}
# 0.5108057092055073 0.41957707773456404 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 11}
# 0.5205176897935999 0.42273648584432966 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 12}
# 0.5315377178492693 0.43263946477926524 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 13}
# 0.5430072897672333 0.44001132199715504 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 14}
# 0.5554272055794428 0.44502619760943635 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 15}
# 0.5665609104910507 0.4461821015526968 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 16}
# 0.577832127914287 0.441350512642145 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 17}
# 0.5888039060580432 0.44229447232640723 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 18}
# 0.5964341067645307 0.4314587043653672 {'deriv__polyorder': 1, 'deriv__window_length': 3, 'model__n_components': 19}
# 0.31481551999092405 0.2950951311083126 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 2}
# 0.3504111505919812 0.32258695400063403 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 3}
# 0.3785629316970177 0.3362446634627999 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 4}
# 0.3988428811804774 0.35234574072582275 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 5}
# 0.4210120088244689 0.3738452195713366 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 6}
# 0.43351657821631645 0.3781781155293622 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 7}
# 0.46369163409686304 0.3968946336750927 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 8}
# 0.47850349608849907 0.40604451573209477 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 9}
# 0.49622811013799517 0.41320532673128285 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 10}
# 0.507917339270674 0.42302001475442774 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 11}
# 0.5196059003277179 0.42164912703660357 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 12}
# 0.5303090694902102 0.4304436758155408 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 13}
# 0.53973509829352 0.43664180318718354 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 14}
# 0.54892502242978 0.4439975939559246 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 15}
# 0.5623618511951091 0.4454183174535908 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 16}
# 0.5721047726871217 0.44215824173905877 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 17}
# 0.5819250492575329 0.437557237911092 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 18}
# 0.5887356905817731 0.43753913672485284 {'deriv__polyorder': 1, 'deriv__window_length': 5, 'model__n_components': 19}
# 0.31257411111663114 0.29366548042748675 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 2}
# 0.3492983292801199 0.32274859580380516 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 3}
# 0.3802076255655146 0.3353974033999374 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 4}
# 0.3991905654520922 0.35282187359119216 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 5}
# 0.4178160938444351 0.37263213823185 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 6}
# 0.4304637436882187 0.376837214587959 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 7}
# 0.4513720968575591 0.39009265102779805 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 8}
# 0.47360339560283027 0.40316109129972433 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 9}
# 0.48925661230018774 0.4119876683060988 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 10}
# 0.5016923016664098 0.4164834256741318 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 11}
# 0.5124509077666632 0.4216014691894304 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 12}
# 0.5217391732950617 0.42862729620525897 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 13}
# 0.5339287228079911 0.4367490796800964 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 14}
# 0.543544974622411 0.44150502436149197 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 15}
# 0.5574025071918236 0.44338341894321437 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 16}
# 0.5672073838478363 0.4412259648104772 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 17}
# 0.5766060384664423 0.4369272454731425 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 18}
# 0.5831531610899033 0.4369809447144458 {'deriv__polyorder': 1, 'deriv__window_length': 7, 'model__n_components': 19}
# 0.3094614165927772 0.29142472548635123 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 2}
# 0.34701628933032885 0.3220643279202183 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 3}
# 0.3713271965977448 0.3321641132633754 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 4}
# 0.3962351455394881 0.3500854341858691 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 5}
# 0.41259506923168116 0.36558544267275006 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 6}
# 0.4267134999929702 0.37460239371518783 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 7}
# 0.44458658252114186 0.386604185200569 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 8}
# 0.46784886433369965 0.4001075231349939 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 9}
# 0.48432742646760796 0.40677218795793646 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 10}
# 0.49857280530650955 0.4138893376982704 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 11}
# 0.5088449356312814 0.4192827043228662 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 12}
# 0.5178442083623429 0.4273521871216336 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 13}
# 0.5298921191025927 0.43649153628313225 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 14}
# 0.5399059179967495 0.4412988368004981 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 15}
# 0.5531216719017499 0.4434604049585711 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 16}
# 0.5633232397305289 0.4420186200276055 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 17}
# 0.5726221831755235 0.4382298379093135 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 18}
# 0.5785713985961796 0.4377150622524033 {'deriv__polyorder': 1, 'deriv__window_length': 9, 'model__n_components': 19}
# 0.30585978983435674 0.28875838692688377 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 2}
# 0.34324229570133113 0.32020950452849134 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 3}
# 0.35905071298049573 0.3276945649845431 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 4}
# 0.3907591730437514 0.3443703542107076 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 5}
# 0.4053515132483211 0.3617085350688491 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 6}
# 0.42206688082137955 0.371705917334913 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 7}
# 0.4388505267056811 0.3826794818726305 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 8}
# 0.46284373405604945 0.39743629666178315 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 9}
# 0.48140576298340515 0.4006325003389515 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 10}
# 0.4952943718350376 0.4082229010407732 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 11}
# 0.5054049465014783 0.41583783578646405 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 12}
# 0.5142995557745877 0.4243745907317883 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 13}
# 0.5249557540256609 0.4346935251328465 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 14}
# 0.53554454075912 0.440167227688236 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 15}
# 0.54788068461822 0.44308059360079916 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 16}
# 0.5593738730180231 0.4418067630311498 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 17}
# 0.5684538245226547 0.4388109989358498 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 18}
# 0.574670301945279 0.4399264689897111 {'deriv__polyorder': 1, 'deriv__window_length': 11, 'model__n_components': 19}

# %%
print('R2 on traint set with best estimator: ', grid_search.best_estimator_.score(X_train, y_train))
print('R2 on test set with best estimator: ', grid_search.best_estimator_.score(X_test, y_test))
# Out:
# R2 on traint set with best estimator:  0.5543724075952687
# R2 on test set with best estimator:  0.41495689652680884
