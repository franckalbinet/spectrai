# %% [markdown]
# ### 0. DATA IMPORT & CLEANING
# ___

# %%
import pandas as pd
import matplotlib.pyplot as plt

# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %% [markdown]
# ### I. Loading Romina's (ARG) data

# %%
from spectrai.datasets.astorga_arg import (load_spectra, load_measurements, load_data)

# %% [markdown]
# #### I.1 Spectra

# %%
# Load
df = load_spectra()
df.reset_index().plot(x='wavenumber', y=df.columns[1:], legend=False, figsize=(15, 8)).invert_xaxis()

# %%
df.head()
# Out:
#                 AR01      AR02      AR03      AR04      AR05      AR06  \
# wavenumber
# 3999.808    0.048893  0.145164 -0.030878  0.056050 -0.011685  0.042582
# 3999.326    0.048938  0.145192 -0.030839  0.056054 -0.011583  0.042685
# 3998.844    0.049019  0.145251 -0.030763  0.056100 -0.011454  0.042803
# 3998.362    0.049132  0.145337 -0.030655  0.056189 -0.011307  0.042936
# 3997.880    0.049265  0.145440 -0.030520  0.056313 -0.011150  0.043080
#
#                 AR07      AR08      AR09      AR10  ...      AR21      AR22  \
# wavenumber                                          ...
# 3999.808    0.031182  0.048815  0.010951 -0.045550  ...  0.025065  0.049695
# 3999.326    0.031278  0.048883  0.011025 -0.045477  ...  0.025120  0.049782
# 3998.844    0.031394  0.048960  0.011113 -0.045374  ...  0.025200  0.049887
# 3998.362    0.031526  0.049039  0.011205 -0.045241  ...  0.025300  0.050001
# 3997.880    0.031670  0.049117  0.011298 -0.045080  ...  0.025419  0.050117
#
#                 AR23      AR24      AR25      AR26      AR27      AR28  \
# wavenumber
# 3999.808    0.091954  0.083659 -0.054411 -0.051096 -0.023185 -0.046925
# 3999.326    0.092022  0.083741 -0.054485 -0.051159 -0.023245 -0.046996
# 3998.844    0.092103  0.083834 -0.054548 -0.051207 -0.023293 -0.047050
# 3998.362    0.092187  0.083931 -0.054607 -0.051245 -0.023337 -0.047093
# 3997.880    0.092267  0.084024 -0.054663 -0.051276 -0.023378 -0.047127
#
#                 AR29      AR30
# wavenumber
# 3999.808   -0.042485 -0.029995
# 3999.326   -0.042562 -0.030073
# 3998.844   -0.042627 -0.030136
# 3998.362   -0.042687 -0.030188
# 3997.880   -0.042744 -0.030231
#
# [5 rows x 30 columns]

# %% [markdown]
# #### I.2 Measurements

# %%
load_measurements().head(20)
# Out:
#    Arg Code      Fe       Ti      Ca        P      Ba
# 1      AR01    2.99  0.37405   2.448  0.17285  511.85
# 2      AR02  5.2215   0.4446  3.4865  0.07335   358.9
# 3      AR03   3.875  0.46265  2.1445  0.11105   563.8
# 4      AR04  5.3215   0.5126    3.79   0.1119   375.3
# 5      AR05  3.3445  0.40035  3.3665   0.1465  529.95
# 6      AR06   3.047  0.37485  3.2445   0.1183   546.6
# 7      AR07  3.7825  0.45465  2.7685  0.11275   531.6
# 8      AR08   4.543  0.46795   2.914  0.09495   480.8
# 9      AR09  3.6335   0.4354     2.8  0.14125   549.2
# 10     AR10  3.0725  0.38325   3.099  0.10295  547.75
# 11     AR11   2.913  0.36465  3.2185   0.3881  496.65
# 12     AR12  6.1025  0.58525   3.172   0.1052  468.45
# 13     AR13  3.3985  0.41895  2.8715  0.09465   626.3
# 14     AR14  5.7265   0.5375   3.325   0.0971  466.95
# 15     AR15  3.9755    0.465  2.3235   0.1185  472.15
# 16     AR16   3.481   0.4284   2.324  0.10185  547.55
# 17     AR17   3.278  0.40845   3.057   0.1456   527.9
# 18     AR18   2.917  0.37425   3.099  0.39775   477.7
# 19     AR19   4.046   0.4634  3.1915  0.09415   501.8
# 20     AR20  3.6245   0.4579   2.493  0.10845  549.35

# %% [markdown]
# #### I.3 All data bundled as NumPy arrays (ML/DL ready)

# %%
X, X_names, y, y_names, instances_id = load_data()
print('X shape: ', X.shape)
print(y_names)
print(instances_id)
# Out:
# X shape:  (30, 7467)
# ['Fe' 'Ti' 'Ca' 'P' 'Ba']
# ['AR01' 'AR02' 'AR03' 'AR04' 'AR05' 'AR06' 'AR07' 'AR08' 'AR09' 'AR10'
#  'AR11' 'AR12' 'AR13' 'AR14' 'AR15' 'AR16' 'AR17' 'AR18' 'AR19' 'AR20'
#  'AR21' 'AR22' 'AR23' 'AR24' 'AR25' 'AR26' 'AR27' 'AR28' 'AR29' 'AR30']

# %%
X_names
# Out:
# array([3999.808 , 3999.326 , 3998.844 , ...,  401.138 ,  400.6559,
#         400.1737])

# %%
X.shape
# Out:
# (30, 7467)

# %%
y_names
# Out:
# array(['Fe', 'Ti', 'Ca', 'P', 'Ba'], dtype=object)

# %%
instances_id
# Out:
# array(['AR01', 'AR02', 'AR03', 'AR04', 'AR05', 'AR06', 'AR07', 'AR08',
#        'AR09', 'AR10', 'AR11', 'AR12', 'AR13', 'AR14', 'AR15', 'AR16',
#        'AR17', 'AR18', 'AR19', 'AR20', 'AR21', 'AR22', 'AR23', 'AR24',
#        'AR25', 'AR26', 'AR27', 'AR28', 'AR29', 'AR30'], dtype=object)

# %% [markdown]
# ### II. Loading Petra's (VNM) data

# %%
from spectrai.datasets.schmitter_vnm import (load_spectra, load_spectra_rep, load_measurements, load_data)

# %% [markdown]
# #### II.1 Spectra

# %%
df = load_spectra()
df.reset_index().plot(x='wavenumber', y=df.columns[1:], legend=False, figsize=(15, 8)).invert_xaxis()

# %% [markdown]
# #### II.2 Spectra with replicates

# %%
df_petra_rep = load_spectra()
df_petra_rep.head()
# Out:
#                 Av217     Av377     Av365     Av005     Av255     Av147  \
# wavenumber
# 3997.767341 -1.783043 -1.788348 -1.716337 -1.841936 -1.798229 -1.735128
# 3995.838848 -1.782792 -1.787620 -1.715937 -1.841396 -1.797634 -1.735202
# 3993.910354 -1.782173 -1.786821 -1.715307 -1.840620 -1.796882 -1.734833
# 3991.981860 -1.781446 -1.786228 -1.714621 -1.839656 -1.795966 -1.734105
# 3990.053367 -1.780489 -1.785376 -1.713585 -1.838708 -1.794621 -1.733166
#
#                 Av110   NF1 2.3     Av376     Av373  ...     Av008   F1 1.3B  \
# wavenumber                                           ...
# 3997.767341 -1.773265 -1.775761 -1.878847 -1.811330  ... -1.851622 -1.803499
# 3995.838848 -1.772599 -1.775335 -1.878022 -1.810733  ... -1.850882 -1.803040
# 3993.910354 -1.771829 -1.774529 -1.877157 -1.809971  ... -1.849908 -1.802211
# 3991.981860 -1.770931 -1.773478 -1.876440 -1.809163  ... -1.848888 -1.801080
# 3990.053367 -1.769945 -1.772323 -1.875250 -1.808129  ... -1.847862 -1.799818
#
#                 Av435     Av077     Av032     Av043     Av063     Av105  \
# wavenumber
# 3997.767341 -7.987279 -1.861870 -1.724403 -1.886424 -1.833019 -1.734137
# 3995.838848 -7.984321 -1.860908 -1.724209 -1.885436 -1.832316 -1.733918
# 3993.910354 -7.979495 -1.859781 -1.723982 -1.884291 -1.831594 -1.733614
# 3991.981860 -7.970919 -1.858708 -1.723541 -1.883189 -1.831019 -1.733087
# 3990.053367 -7.954866 -1.857778 -1.722957 -1.882078 -1.830449 -1.732356
#
#              NF1 4.4A     Av061
# wavenumber
# 3997.767341 -1.853784 -1.796756
# 3995.838848 -1.852821 -1.796069
# 3993.910354 -1.851973 -1.795363
# 3991.981860 -1.851169 -1.794816
# 3990.053367 -1.849830 -1.794339
#
# [5 rows x 147 columns]

# %% [markdown]
# * **Prepare lookup tables for group of replicates**

# %%
VIETNAM_LOOKUP_URL = os.path.join(DATA_PATH, 'vnm-petra', 'vietnam-petra', 'Overview list.xls')

# %%
df_lookup = pd.read_excel(VIETNAM_LOOKUP_URL, sheet_name='Petra 1.1', usecols=[0,2,3], names=['group_id', 'spectra_id', 'mir_label'])
df_lookup.fillna(method='ffill', inplace=True)
#df_lookup = df_lookup.astype(int)
df_lookup['spectra_id'] = df_lookup['spectra_id'].astype(int)
df_lookup.head()
# Out:
#    group_id  spectra_id mir_label
# 0       1.0        3179   NF1 1.1
# 1       1.0        3180   NF1 1.1
# 2       1.0        3181   NF1 1.1
# 3       2.0        3182   NF1 1.2
# 4       2.0        3183   NF1 1.2

# %%
lookup_tot_spectra_id = {}
for name, group in df_lookup.groupby('mir_label'):
    lookup_tot_spectra_id[name] = group['spectra_id'].values

# %%
lookup_tot_spectra_id
# Out:
# {' Overwritten with 4600!': array([4500, 4501]),
#  'F1 1.1A': array([3281, 3282, 3283]),
#  'F1 1.1B': array([3284, 3285, 3286]),
#  'F1 1.2A': array([3299, 3300, 3301]),
#  'F1 1.2B': array([3302, 3303, 3304]),
#  'F1 1.3A': array([3305, 3306, 3307]),
#  'F1 1.3B': array([3308, 3309, 3310]),
#  'F1 1.4A': array([3311, 3312, 3313]),
#  'F1 1.4B': array([3314, 3315, 3316]),
#  'F1 1.5A': array([3317, 3318, 3319]),
#  'F1 1.5B': array([3320, 3321, 3322]),
#  'F1 2.1': array([3476, 3477, 3478]),
#  'F1 2.2': array([3479, 3480, 3481]),
#  'F1 2.3': array([3482, 3483, 3484]),
#  'F1 2.4': array([3485, 3486, 3487]),
#  'F1 2.5': array([3488, 3489, 3490]),
#  'F1 2.6': array([3491, 3492, 3493]),
#  'F1 3.1': array([3494, 3495, 3496]),
#  'F1 3.2': array([3497, 3498, 3499]),
#  'F1 3.3': array([3500, 3501, 3502, 3503]),
#  'F1 3.4': array([3504, 3505, 3506, 3507]),
#  'F1 3.5': array([3508, 3509, 3510]),
#  'F1 3.6': array([3511, 3512, 3513]),
#  'F1 4.1A': array([3518, 3519, 3520]),
#  'F1 4.1B': array([3521, 3522, 3523]),
#  'F1 4.2A': array([3524, 3525, 3526, 3527]),
#  'F1 4.2B': array([3528, 3529, 3530, 3531]),
#  'F1 4.3A': array([3532, 3533, 3534]),
#  'F1 4.3B': array([3535, 3536, 3536, 3537]),
#  'F1 4.4A': array([3538, 3539, 3540]),
#  'F1 4.4B': array([3541, 3542, 3543, 3544]),
#  'F1 4.5A': array([3545, 3546, 3547]),
#  'F1 4.5B': array([3548, 3549, 3550]),
#  'F1 4.6A': array([3684, 3685, 3686]),
#  'F1 4.6B': array([3687, 3688, 3689]),
#  'F1 4.7A': array([3690, 3691, 3692]),
#  'F1 4.7B': array([3693, 3694, 3695]),
#  'F1 4.8A': array([3696, 3697, 3698]),
#  'F1 4.8B': array([3699, 3700, 3701, 3702]),
#  'F4 1.1': array([4123, 4124, 4125]),
#  'F4 1.2': array([4126, 4127, 4128]),
#  'F4 1.3': array([4129, 4130, 4131]),
#  'F4 1.4': array([4132, 4133, 4134]),
#  'F4 1.5': array([4135, 4136, 4137]),
#  'F4 2.1': array([4138, 4139, 4140]),
#  'F4 2.2': array([4141, 4142, 4143]),
#  'F4 2.3': array([4144, 4145, 4146, 4147]),
#  'F4 2.4': array([4148, 4149, 4150]),
#  'F4 2.5': array([4151, 4152, 4153]),
#  'F4 2.6': array([4154, 4155, 4156]),
#  'F4 3.1': array([4157, 4158, 4159]),
#  'F4 3.2': array([4160, 4161, 4162]),
#  'F4 3.3': array([4163, 4164, 4165]),
#  'F4 3.4': array([4166, 4167, 4168]),
#  'F4 3.5': array([4169, 4170, 4171]),
#  'F4 3.6': array([4172, 4173, 4174]),
#  'F4 4.1': array([4175, 4176, 4177]),
#  'F4 4.2': array([4178, 4179, 4180]),
#  'F4 4.3': array([4181, 4182, 4183]),
#  'F4 4.4': array([4184, 4185, 4186]),
#  'F4 4.5': array([4187, 4188, 4189]),
#  'F4 4.6': array([4190, 4191, 4192]),
#  'F4 5.1': array([4193, 4194, 4195]),
#  'F4 5.2': array([4196, 4197, 4198]),
#  'F4 5.3': array([4199, 4200, 4201]),
#  'F4 5.4': array([4202, 4203, 4204]),
#  'F4 5.5': array([4205, 4206, 4207]),
#  'F4 5.6': array([4208, 4209, 4210]),
#  'F4 6.1': array([4211, 4212, 4213]),
#  'F4 6.2': array([4214, 4215, 4216]),
#  'F4 6.3': array([4217, 4218, 4219]),
#  'F4 6.4': array([4220, 4221, 4222]),
#  'F4 6.5': array([4223, 4224, 4225]),
#  'F4 6.6': array([4226, 4227, 4228]),
#  'F4 7.1': array([4229, 4230, 4231]),
#  'F4 7.2': array([4232, 4233, 4234]),
#  'F4 7.3': array([4235, 4236, 4237]),
#  'F4 7.4': array([4238, 4239, 4240]),
#  'F4 7.5': array([4241, 4242, 4243]),
#  'F5 1.1': array([4559, 4560, 4561]),
#  'F5 1.2': array([4562, 4563, 4564]),
#  'F5 1.3': array([4565, 4566, 4567]),
#  'F5 1.4': array([4568, 4569, 4570]),
#  'F5 1.5': array([4571, 4572, 4573]),
#  'F5 2.1': array([4574, 4575, 4576]),
#  'F5 2.2': array([4577, 4578, 4579]),
#  'F5 2.3': array([4580, 4581, 4582]),
#  'F5 2.4': array([4583, 4584, 4585]),
#  'F5 2.5': array([4586, 4587, 4588]),
#  'F5 2.6': array([4589, 4590, 4591]),
#  'F5 2.7': array([4592, 4593, 4594]),
#  'F5 2.8': array([4595, 4596, 4597]),
#  'F5 3.1': array([4598, 4599]),
#  'F5 3.2': array([4601, 4602, 4603]),
#  'F5 3.3': array([4604, 4605, 4606]),
#  'F5 3.4': array([4607, 4608, 4609]),
#  'F5 3.5': array([4610, 4611, 4612]),
#  'F5 3.6': array([4613, 4614, 4615]),
#  'F5 4.1': array([4684, 4685, 4686]),
#  'F5 4.2': array([4687, 4688, 4689]),
#  'F5 4.3': array([4690, 4691, 4692]),
#  'F5 4.4': array([4693, 4694, 4695]),
#  'F5 4.5': array([4696, 4697, 4698]),
#  'F5 4.6': array([4699, 4700, 4701, 4702]),
#  'F5 5.1': array([4703, 4704, 4705]),
#  'F5 5.2': array([4706, 4707, 4708]),
#  'F5 5.3': array([4709, 4710, 4711]),
#  'F5 5.4': array([4712, 4713, 4714]),
#  'F5 5.5': array([4715, 4716, 4717, 4718]),
#  'F5 5.6': array([4719, 4720, 4721]),
#  'F5 6.1': array([4722, 4723, 4724]),
#  'F5 6.2': array([4725, 4726, 4727]),
#  'F5 6.3': array([4728, 4729, 4730]),
#  'F5 6.4': array([4731, 4732, 4733]),
#  'F5 7.1': array([4734, 4735, 4736]),
#  'F5 7.2': array([4737, 4738, 4739]),
#  'F5 7.3': array([4740, 4741, 4742]),
#  'F5 7.4': array([4743, 4744, 4745]),
#  'F5 7.5': array([4746, 4747, 4748]),
#  'F5 7.6': array([4749, 4750, 4751]),
#  'MEASURED AS 4500': array([4600]),
#  'NF1 1.1': array([3179, 3180, 3181]),
#  'NF1 1.2': array([3182, 3183, 3184]),
#  'NF1 1.3': array([3185, 3186, 3187]),
#  'NF1 1.4': array([3188, 3189, 3190]),
#  'NF1 1.5': array([3191, 3192, 3193]),
#  'NF1 1.6': array([3194, 3195, 3196]),
#  'NF1 2.1': array([3197, 3198, 3199]),
#  'NF1 2.2': array([3200, 3201, 3202]),
#  'NF1 2.3  ': array([3203, 3204, 3205]),
#  'NF1 2.4': array([3206, 3207, 3208]),
#  'NF1 2.5': array([3209, 3210, 3211]),
#  'NF1 2.6': array([3212, 3213, 3214]),
#  'NF1 3.1': array([3215, 3216, 3217]),
#  'NF1 3.2': array([3218, 3219, 3220]),
#  'NF1 3.3': array([3221, 3222, 3223]),
#  'NF1 3.4': array([3224, 3225, 3226]),
#  'NF1 3.5': array([3227, 3228, 3229]),
#  'NF1 3.6': array([3230, 3231, 3232]),
#  'NF1 4.1A': array([3233, 3234, 3235]),
#  'NF1 4.1B': array([3236, 3237, 3238]),
#  'NF1 4.2A': array([3239, 3240, 3241]),
#  'NF1 4.2B': array([3242, 3243, 3244]),
#  'NF1 4.3A': array([3245, 3246, 3247]),
#  'NF1 4.3B': array([3248, 3249, 3250]),
#  'NF1 4.4A': array([3251, 3252, 3253]),
#  'NF1 4.4B': array([3254, 3255, 3256]),
#  'NF1 4.5A': array([3257, 3258, 3259]),
#  'NF1 4.5B': array([3260, 3261, 3262]),
#  'NF1 4.6A': array([3263, 3264, 3265]),
#  'NF1 4.6B': array([3266, 3267, 3268]),
#  'NF1 4.7A': array([3269, 3270, 3271]),
#  'NF1 4.8A': array([3275, 3276, 3277]),
#  'NF1 4.8B': array([3278, 3279, 3280]),
#  'NF14.7B': array([3272, 3273, 3274]),
#  'NF4 1.1': array([4487, 4488, 4489]),
#  'NF4 1.2': array([4490, 4491, 4492]),
#  'NF4 2.1': array([4493, 4494, 4495]),
#  'NF4 2.2': array([4496, 4497, 4498, 4922, 4922, 4922, 5299, 5299, 5299, 5299, 5299,
#         5299, 5299, 5299, 5299, 5299, 5299, 5299, 5299, 5299, 5299, 5299,
#         5299, 5299, 5299, 5299, 5299, 5299, 5299, 5299, 5299]),
#  'NF4 2.3': array([4499]),
#  'NF4 2.4': array([4502, 4503, 4504]),
#  'NF4 2.5': array([4505, 4506, 4507]),
#  'NF4 2.6': array([4508, 4509, 4510]),
#  'NF4 3.1A': array([4511, 4512, 4513]),
#  'NF4 3.2A': array([4514, 4515, 4516]),
#  'NF4 3.3A': array([4517, 4518, 4519]),
#  'NF4 3.4A': array([4520, 4521, 4522]),
#  'NF4 3.5A': array([4523, 4524, 4525]),
#  'NF4 3.6A': array([4526, 4527, 4528]),
#  'NF4 4.1': array([4529, 4530, 4531]),
#  'NF4 4.2': array([4532, 4533, 4534]),
#  'NF4 4.3': array([4535, 4536, 4537]),
#  'NF4 4.4': array([4538, 4539, 4540]),
#  'NF4 4.5': array([4541, 4542, 4543]),
#  'NF4 4.6': array([4544, 4545, 4546]),
#  'NF4 5.1': array([4547, 4548]),
#  'NF4 5.2 MISSING': array([4548, 4549]),
#  'NF4 5.3': array([4550, 4551, 4552]),
#  'NF4 5.4': array([4553, 4554, 4555]),
#  'NF4 5.5': array([4556, 4557, 4558]),
#  'NF5 1.1': array([4752, 4753, 4754]),
#  'NF5 1.2': array([4755, 4756, 4757]),
#  'NF5 1.3': array([4758, 4759, 4760]),
#  'NF5 1.4': array([4761, 4762, 4763]),
#  'NF5 1.5': array([4764, 4765, 4766]),
#  'NF5 2.1': array([4767, 4768, 4769]),
#  'NF5 2.2': array([4770, 4771, 4772]),
#  'NF5 2.3': array([4773, 4774, 4775]),
#  'NF5 2.4': array([4776, 4777, 4778]),
#  'NF5 2.5': array([4779, 4780, 4781]),
#  'NF5 2.6': array([4782, 4783, 4784]),
#  'NF5 2.7': array([4785, 4786, 4787]),
#  'NF5 2.8': array([4788, 4789, 4790]),
#  'NF5 3.1': array([4836, 4837, 4838]),
#  'NF5 3.2': array([4839, 4840, 4841]),
#  'NF5 3.3': array([4842, 4843, 4844]),
#  'NF5 3.4': array([4845, 4846, 4847]),
#  'NF5 3.5': array([4848, 4849, 4850]),
#  'NF5 3.6': array([4851, 4852, 4853]),
#  'NF5 4.1': array([4854, 4855, 4856, 4857]),
#  'NF5 4.2': array([4858, 4859, 4860]),
#  'NF5 4.3': array([4861, 4862, 4863]),
#  'NF5 4.4': array([4864, 4865, 4866]),
#  'NF5 4.5': array([4867, 4868, 4869]),
#  'NF5 4.6': array([4870, 4871, 4872, 4873]),
#  'NF5 5.1': array([4874, 4875, 4876]),
#  'NF5 5.2': array([4877, 4878, 4879]),
#  'NF5 5.3': array([4880, 4881, 4882]),
#  'NF5 5.4': array([4883, 4884, 4885]),
#  'NF5 5.5': array([4886, 4887, 4888]),
#  'NF5 5.6': array([4889, 4890, 4891]),
#  'NF5 6.1': array([4892, 4893, 4894]),
#  'NF5 6.2': array([4895, 4896, 4897]),
#  'NF5 6.3': array([4898, 4899, 4900]),
#  'NF5 6.4': array([4901, 4902, 4903]),
#  'NF5 7.1': array([4904, 4905, 4906]),
#  'NF5 7.2': array([4907, 4908, 4909]),
#  'NF5 7.3': array([4910, 4911, 4912]),
#  'NF5 7.4': array([4913, 4914, 4915]),
#  'NF5 7.5': array([4916, 4917, 4918]),
#  'NF5 7.6': array([4919, 4920, 4921])}

# %%
TOTAL_LABEL = 'F4 1.1'
df_group = df_petra_rep[lookup_tot_spectra_id[TOTAL_LABEL]]
df_group = df_group.apply(lambda x: x - df_group.mean(axis=1))

df_group.plot().invert_xaxis()
all_values = df_group.values.flatten()

with plt.style.context(('ggplot')):
    fig, ax = plt.subplots(figsize=(16, 5))
    ax.hist(all_values, bins=100)

# %%
# Is labeled data the mean of replicates?
DATA_PATH = os.path.join('..', 'data')
VIETNAM_PATH =  os.path.join('vnm-petra', 'mir-models')
DATA_URL = os.path.join(DATA_PATH, VIETNAM_PATH, '*.*')
VIETNAM_MEAS_URL = os.path.join(DATA_PATH, 'vnm-petra', 'mir-models', '20090215-soil-database-mirs.xls')

X, X_names, y, y_names, instances_id, lookup_tot_mir_label = spa.load_data_petra(DATA_URL, VIETNAM_MEAS_URL)
lookup_tot_mir_label
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-f9304dd14502> in <module>
#       6 VIETNAM_MEAS_URL = os.path.join(DATA_PATH, 'vnm-petra', 'mir-models', '20090215-soil-database-mirs.xls')
#       7
# ----> 8 X, X_names, y, y_names, instances_id, lookup_tot_mir_label = spa.load_data(DATA_URL, VIETNAM_MEAS_URL)
#       9 lookup_tot_mir_label
#
# NameError: name 'spa' is not defined

# %%
# Replicates for TOTAL_LABEL
df_rep_vs_sel = df_petra_rep[lookup_tot_spectra_id[TOTAL_LABEL]]
df_rep_vs_sel.head()
# Out:
#                  4123      4124      4125
# wavenumber
# 3997.754689 -0.140290  0.029159  0.036384
# 3995.826201 -0.140014  0.029361  0.036651
# 3993.897714 -0.139677  0.029607  0.036847
# 3991.969226 -0.139323  0.029862  0.036998
# 3990.040739 -0.138998  0.030084  0.037177

# %%
def normalize(X):
    return (X - X.min()) / (X.max() - X.min())

# %%
normalize(X[row_spectra,:])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-2e3c6eaa3f2c> in <module>
# ----> 1 normalize(X[row_spectra,:])
#
# NameError: name 'row_spectra' is not defined

# %%
row_spectra = list(instances_id).index(lookup_tot_mir_label[TOTAL_LABEL])
df_rep_vs_sel['selected'] = normalize(X[row_spectra,:]).tolist()
df_rep_vs_sel

# %%
df_rep_vs_sel.reset_index().plot(x='wavenumber', y=df_rep_vs_sel.columns[0:], legend=True, figsize=(15, 8)).invert_xaxis()

# %% [markdown]
# #### II.3 Measurements

# %%
load_measurements()
# Out:
#           total_label        TC     TOC       TIC    TN        CEC         K  \
# mir_label
# Av001          F4 1.1  1.142395  1.0800  0.062395  0.16   4.545833   6.17500
# Av003          F4 1.3  2.155918  1.2200  0.935918  0.16   7.451389   6.47000
# Av005          F4 1.5  1.299190  1.1900  0.109190  0.17   8.271528   6.62000
# Av008          F4 2.3  1.689977  1.4300  0.259977  0.21   9.727083   7.23000
# Av013          F4 3.2  2.099544  1.4600  0.639544  0.19   9.338889   8.03000
# ...               ...       ...     ...       ...   ...        ...       ...
# NF1 4.1B     NF1 4.1B  1.630000  1.4068  0.223200  0.13   9.594444   7.95405
# NF1 4.4A     NF1 4.4A  2.420000  2.2280  0.192000  0.20  11.570139   9.57916
# NF1 4.4B     NF1 4.4B  2.180000  1.7744  0.405600  0.16  10.481250   7.64498
# NF1 4.8A     NF1 4.8A  2.330000  2.1272  0.202800  0.21  10.188889  10.52631
# NF1 4.8B     NF1 4.8B  2.560000  2.2948  0.265200  0.19  10.700694   9.86829
#
#              FCAVER   FCIAVER   FSAAVER
# mir_label
# Av001      0.110000  0.544000  0.346000
# Av003      0.158000  0.481333  0.360667
# Av005      0.114125  0.587000  0.298875
# Av008      0.171000  0.523500  0.305500
# Av013      0.142500  0.660500  0.197000
# ...             ...       ...       ...
# NF1 4.1B   0.136500  0.730500  0.133000
# NF1 4.4A   0.137500  0.804000  0.058500
# NF1 4.4B   0.141000  0.795000  0.064000
# NF1 4.8A   0.142000  0.804000  0.054000
# NF1 4.8B   0.143000  0.779750  0.077250
#
# [131 rows x 10 columns]

# %% [markdown]
# #### II.4 All data bundled as NumPy arrays (ML/DL ready)

# %%
X, X_names, y, y_names, instances_id, lookup = load_data()
print('X shape: ', X.shape)
print(lookup)
print(y_names)
print(instances_id)
# Out:
# X shape:  (130, 1763)
# {'F4 1.1': 'Av001', 'F4 1.3': 'Av003', 'F4 1.5': 'Av005', 'F4 2.3': 'Av008', 'F4 3.2': 'Av013', 'F4 3.3': 'Av014', 'F4 4.1': 'Av018', 'F4 4.3': 'Av020', 'F4 4.6': 'Av023', 'F4 5.3': 'Av026', 'F4 5.4': 'Av027', 'F4 6.3': 'Av032', 'F4 7.1': 'Av036', 'F4 7.3': 'Av038', 'F4 7.5': 'Av040', 'NF4 1.1': 'Av041', 'NF4 1.2': 'Av042', 'NF4 2.1': 'Av043', 'NF4 2.3': 'Av045', 'NF4 2.6': 'Av048', 'NF4 3.3a': 'Av051', 'NF4 4.3': 'Av057', 'NF4 5.1': 'Av061', 'NF4 5.3': 'Av062', 'NF4 5.4': 'Av063', 'NF4 5.5': 'Av064', 'F5 1.1': 'Av065', 'F5 1.3': 'Av067', 'F5 1.5': 'Av069', 'F5 2.3': 'Av072', 'F5 2.8': 'Av077', 'F5 3.3': 'Av080', 'F5 3.6': 'Av083', 'F5 4.3': 'Av086', 'F5 5.3': 'Av092', 'F5 6.3': 'Av098', 'F5 7.1': 'Av100', 'F5 7.3': 'Av102', 'F5 7.6': 'Av105', 'NF5 1.1': 'Av106', 'NF5 1.3': 'Av108', 'NF5 1.5': 'Av110', 'NF5 2.3': 'Av113', 'NF5 3.3': 'Av121', 'NF5 4.3': 'Av127', 'NF5 5.3': 'Av133', 'NF5 6.3': 'Av139', 'NF5 7.1': 'Av141', 'NF5 7.3': 'Av143', 'NF5 7.6': 'Av146', '2F6 1.1': 'Av147', '2F6 1.3': 'Av149', '2F6 1.6': 'Av152', '2F6 2.3': 'Av155', '2F6 3.3': 'Av161', '2F6 4.3': 'Av165', '2F6 5.1': 'Av169', '2F6 5.3': 'Av171', '2F6 5.6': 'Av174', '2NF6 1.1': 'Av175', '2NF6 1.3': 'Av177', '2NF6 1.6': 'Av180', '2NF6 2.3': 'Av183', '2NF6 3.3': 'Av189', '2NF6 4.3A': 'Av195', '2NF6 5.1': 'Av203', '2NF6 5.3': 'Av205', '2NF6 5.6': 'Av208', 'F2 1.1': 'Av209', 'F2 1.3': 'Av211', 'F2 1.6': 'Av214', 'F2 2.3': 'Av217', 'F2 3.3A': 'Av225', 'F2 3.3B': 'Av226', 'F2 4.3': 'Av235', 'F2 5.1': 'Av239', 'F2 5.4': 'Av242', 'F2 5.6': 'Av244', 'F2 5.8': 'Av246', 'NF2 1.1': 'Av247', 'NF2 1.3': 'Av249', 'NF2 1.6': 'Av252', 'NF2 2.3': 'Av255', 'NF2 3.3': 'Av261', 'NF2 4.1': 'Av265', 'NF2 4.3': 'Av267', 'NF2 4.4': 'Av268', 'NF2 4.8': 'Av272', 'C0': 'Av365', 'C1': 'Av366', 'C3': 'Av367', 'C5': 'Av368', 'E0': 'Av369', 'E1': 'Av370', 'E2': 'Av371', 'E3': 'Av372', 'E4A': 'Av373', 'E4B': 'Av374', 'E5': 'Av375', 'E6': 'Av376', 'E7': 'Av377', 'Sed7116F1': 'Av378', 'Sed7116F2': 'Av379', 'Sed7116NF4': 'Av380', 'F1 1.1A': 'F1 1.1A', 'F1 1.1B': 'F1 1.1B', 'F1 1.3A': 'F1 1.3A', 'F1 1.3B': 'F1 1.3B', 'F1 1.6A': 'F1 1.6A', 'F1 1.6B': 'F1 1.6B', 'F1 2.3': 'F1 2.3', 'F1 3.3': 'F1 3.3', 'F1 4.1A': 'F1 4.1A', 'F1 4.1B': 'F1 4.1B', 'F1 4.4A': 'F1 4.4A', 'F1 4.4B': 'F1 4.4B', 'F1 4.6A': 'F1 4.6A', 'F1 4.8A': 'F1 4.8A', 'NF1 1.1': 'NF1 1.1', 'NF1 1.3': 'NF1 1.3', 'NF1 1.6': 'NF1 1.6', 'NF1 2.3': 'NF1 2.3', 'NF1 2.6': 'NF1 2.6', 'NF1 3.3': 'NF1 3.3', 'NF1 4.1A': 'NF1 4.1A', 'NF1 4.1B': 'NF1 4.1B', 'NF1 4.4A': 'NF1 4.4A', 'NF1 4.4B': 'NF1 4.4B', 'NF1 4.8A': 'NF1 4.8A', 'NF1 4.8B': 'NF1 4.8B'}
# ['TC' 'TOC' 'TIC' 'TN' 'CEC' 'K' 'FCAVER' 'FCIAVER' 'FSAAVER']
# ['Av001' 'Av003' 'Av005' 'Av008' 'Av013' 'Av014' 'Av018' 'Av020' 'Av023'
#  'Av026' 'Av027' 'Av032' 'Av036' 'Av038' 'Av040' 'Av041' 'Av042' 'Av043'
#  'Av045' 'Av048' 'Av051' 'Av057' 'Av061' 'Av062' 'Av063' 'Av064' 'Av065'
#  'Av067' 'Av069' 'Av072' 'Av077' 'Av080' 'Av083' 'Av086' 'Av092' 'Av098'
#  'Av100' 'Av102' 'Av105' 'Av106' 'Av108' 'Av110' 'Av113' 'Av121' 'Av127'
#  'Av133' 'Av139' 'Av141' 'Av143' 'Av146' 'Av147' 'Av149' 'Av152' 'Av155'
#  'Av161' 'Av165' 'Av169' 'Av171' 'Av174' 'Av175' 'Av177' 'Av180' 'Av183'
#  'Av189' 'Av195' 'Av203' 'Av205' 'Av208' 'Av209' 'Av211' 'Av214' 'Av217'
#  'Av225' 'Av226' 'Av235' 'Av239' 'Av242' 'Av244' 'Av246' 'Av247' 'Av249'
#  'Av252' 'Av255' 'Av261' 'Av265' 'Av267' 'Av268' 'Av272' 'Av365' 'Av366'
#  'Av367' 'Av368' 'Av369' 'Av370' 'Av371' 'Av372' 'Av373' 'Av374' 'Av375'
#  'Av376' 'Av377' 'Av378' 'Av379' 'Av380' 'F1 1.1A' 'F1 1.1B' 'F1 1.3A'
#  'F1 1.3B' 'F1 1.6A' 'F1 1.6B' 'F1 2.3' 'F1 3.3' 'F1 4.1A' 'F1 4.1B'
#  'F1 4.4A' 'F1 4.4B' 'F1 4.6A' 'F1 4.8A' 'NF1 1.1' 'NF1 1.3' 'NF1 1.6'
#  'NF1 2.3' 'NF1 2.6' 'NF1 3.3' 'NF1 4.1A' 'NF1 4.1B' 'NF1 4.4A' 'NF1 4.4B'
#  'NF1 4.8A' 'NF1 4.8B']

# %% [markdown]
# ### III. Loading KSSL data

# %% [markdown]
# Note: To read Bruker optics spectra in `*.0` format, two python packages are available:
# 1. https://www.bruker.com/products/infrared-near-infrared-and-raman-spectroscopy/ft-ir-routine-spectrometers/hts-xt.html
# 2. https://stuart-cls.github.io/python-opusfc-dist/
#
# The second one is used.

# %%
from spectrai.datasets.kssl import (load_data)

# %% [markdown]
# #### III.1 Spectra

# %%
X, X_names, y, y_names, instances_id = load_data()

# %%
X.shape
# Out:
# (50714, 1764)

# %%
X_names
# Out:
# array(['3999', '3997', '3995', ..., '603', '601', '599'], dtype=object)

# %%
y.shape
# Out:
# (50714, 3)

# %%
y
# Out:
# array([[ 0.       ,  5.       ,  1.7166334],
#        [ 0.       ,  1.       ,  0.7310265],
#        [10.       ,  8.       ,  2.2634011],
#        ...,
#        [ 5.       ,  5.       ,  0.6496119],
#        [ 0.       ,  5.       ,  1.022008 ],
#        [13.       ,  5.       ,  0.6421454]])

# %%
instances_id
# Out:
# array([ 34967,  68785,  25368, ..., 130526, 130533, 130535])
